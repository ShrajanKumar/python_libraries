# %% [markdown]
#  This notebook teaches you the ropes to get up and running.
#  The matplotlib gallery and documentation are the best resource for
#  learning advanced features.

# %% [markdown]
# Matplotlib is a desktop plotting package designed for creating (mostly two
# dimensional) publication-quality plots.

# %%
#first impport matplotlib library as given below

import matplotlib.pyplot as plt

# %%
#let us draw an simple line graph

import numpy as np

data=np.arange(9)

plt.plot(data)

# %% [markdown]
# ## Figures and Subplots

# %% [markdown]
# Plots in matplotlib reside within a Figure object. You can create a new figure with
#  plt.figure

# %%
fig=plt.figure()

# %% [markdown]
#  In IPython, an empty plot window will appear, but in Jupyter nothing will be shown
#  until we use a few more commands. plt.figure has a number of options; notably,
#  figsize will guarantee the figure has a certain size and aspect ratio.

# %% [markdown]
# You can’t make a plot with a blank figure. You have to create one or more subplots
#  using add_subplot:

# %%
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
fig

# %% [markdown]
# An empty matplotlib figure with three sub figures

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
plt.plot(np.random.randn(40).cumsum(),'k--')

# %% [markdown]
# When you run ploting command matplotlib draws on the last figure and subplot used (creating one if necessary).
# In our previous example plot was drawn in ax3

# %% [markdown]
# The 'k--' is a style option instructing matplotlib to plot a black dashed line.

# %% [markdown]
# To draw in ax1 and ax2 we can run below comand by  calling their name

# %%
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(20),np.arange(20)*3,color='r')
fig

# %% [markdown]
# Note it will be better if you write all comands in single  cell

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
plt.plot(np.random.randn(40).cumsum(),'k--')
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(20),np.arange(20)*3,color='r')

# %% [markdown]
#  Creating a figure with a grid of subplots is a very common task, so matplotlib
#  includes a convenience method, plt.subplots, that creates a new figure and returns
#  a NumPy array containing the created subplot objects

# %%
fig,axes=plt.subplots(2,3)
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
#  You can also indicate that subplots should have the
#  same x- or y-axis using sharex and sharey, respectively. This is especially useful
#  when you’re comparing data on the same scale; otherwise, matplotlib autoscales plot
#  limits independently.

# %% [markdown]
# ### Adjusting the spacing around the subplots

# %% [markdown]
# By default matplotlib leaves a certain amount of padding around the outside of the
#  subplots and spacing between subplots.

# %% [markdown]
# You can
#  change the spacing using the subplots_adjust method on Figure objects, also avail
# able as a top-level function:
#
# subplots_adjust(left=None, bottom=None, right=None, top=None,
#                 wspace=None, hspace=None)

# %%
fig,axes=plt.subplots(2,2 ,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
plt.subplots_adjust(right=3,top=3,wspace=0.2,hspace=0.2)

# %%
fig,axes=plt.subplots(2,2)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
plt.subplots_adjust(wspace=0,hspace=0)

# %% [markdown]
# You may notice that the axis labels overlap. matplotlib doesn’t check whether the
#  labels overlap, so in a case like this you would need to fix the labels yourself by speci
# fying explicit tick locations and tick labels (we’ll look at how to do this in the follow
# ing sections).

# %% [markdown]
# ###  Colors, Markers, and Line Styles

# %% [markdown]
# For example matplotlibs standardplot function takes arrays of x and y values(cordinates) and string abbreviation indicating color and line style which is optional

# %%
plt.plot([1,2,3,4],[5,6,3,7],'k--')

# %% [markdown]
# This way of specifying both color and line style in a string is provided as a convenience.

# %% [markdown]
# Suppose if you want to mention color and style of line sepratiley it is possiblle as below

# %%
plt.plot(range(4),np.random.rand(4),color='r',linestyle='--')

# %% [markdown]
# Line plots can additionally have markers to highlight the actual data points

# %%
plt.plot(np.random.randn(20).cumsum(),'ro--')

# %%
plt.plot(np.random.randn(20).cumsum(),linestyle='--',color='k',marker='o',alpha=0.3)

# %% [markdown]
# suppose if you pass single array of values it will be considered as y axis values and for x axis values will be auto generated in the range of length of y

# %%
plt.plot(range(1,5))

# %% [markdown]
# If you observe x axis values are between 0 and 3

# %% [markdown]
# One can alter the style in which values drawn using drawstyle

# %%
data=np.random.randn(20).cumsum()
plt.plot(data,'k--',alpha=0.3,label='default')
plt.plot(data,'k-',drawstyle='steps-post',label='steps_post')
plt.legend(loc='best')
plt.title('draw_style_practice')
# Out:
# Text(0.5, 1.0, 'draw_style_practice')

# %% [markdown]
# Here, since we passed the label arguments to plot, we are able to create a plot legend to identify each line using plt.legend.
#
# You must call plt.legend (or ax.legend, if you have a reference to
#  the axes) to create the legend, whether or not you passed the label
#  options when plotting the data.

# %% [markdown]
# ## Ticks and titles

# %% [markdown]
# ###### ticks labels titles and ticklabels

# %%
plt.plot(np.random.randn(1000).cumsum())

# %% [markdown]
# This is the defaultt plot now let us define x axis ticks and labels title for graph and x axis labels

# %% [markdown]
#  To change the x-axis ticks, it’s easiest to use set_xticks and set_xticklabels. The
# former instructs matplotlib where to place the ticks along the data range; by default
# these locations will also be the labels. But we can set any other values as the labels
#  using set_xticklabels.
#
#  The rotation option sets the x tick labels at a 30-degree rotation. Lastly, set_xlabel
#  gives a name to the x-axis and set_title the subplot title

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks([0,250,500,750])
ax.set_xticklabels(['one','two','three','four'],rotation=90,fontsize='medium')
ax.set_title('My first plot')
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %% [markdown]
# ###### legends

# %% [markdown]
# Legends are the important component of plots for identifying different plots in a single graph.Easisest way to add legend is to pass labels while adding each piece of graph and in end call .legend()

# %%
from numpy.random import randn as rn

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(rn(1000).cumsum(),'r',label='first')
ax.plot(rn(1000).cumsum(),'k--',label='second')
ax.plot(rn(1000).cumsum(),'g.',label='Third')
ax.legend(loc='best') #setting legend  loc is the location in graph to display legend

#for better understanding of the graph use below 
fig.subplots_adjust(right=1.5,top=1.5)

# %% [markdown]
# 'upper left', 'upper right', 'lower left', 'lower right'  are  some of the other usefull values for loc (legend location)

# %% [markdown]
# ## Plotting with  Pandas and Seaborn

# %% [markdown]
# matplotlib can be a fairly low-level tool. You assemble a plot from its base components: the data display (i.e., the type of plot: line, bar, box, scatter, contour, etc.), legend, title, tick labels, and other annotations.

# %% [markdown]
# In pandas we may have multiple columns of data, along with row and column labels.
#  pandas itself has built-in methods that simplify creating visualizations from Data
# Frame and Series objects. Another usefull library is seaborn

# %% [markdown]
# #### Line plot

# %%
import pandas as pd
import numpy as np
s1=pd.Series(np.random.randn(10).cumsum(),index=np.arange(100,200,10))

s1.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# One can observe that series index is used as x-axis labels. By setting use_index=False one can skip using index as xlabel

# %%
s1.plot(use_index=False,style='k--',alpha=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The x-axis ticks and limits can be
#  adjusted with the xticks and xlim options,  similary can be done for y axis

# %%
s1.plot(style='k--',xticks=[120,140,160],xlim=[100,180])
# Out:
# <AxesSubplot:>

# %% [markdown]
# DataFrame’s plot method plots each of its columns as a different line on the same
#  subplot, creating a legend automatically.

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),columns=['one','two','three','four'],
                index=np.arange(0,100,10))

df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Barplot

# %% [markdown]
# plot.bar() and df.barh() make vertical and horizontal bar plots, respec
# tively.  In bar() index will be used in x axis and in barh()  index will be used in y axis

# %%
s1=pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

fig,axes=plt.subplots(2,1)
s1.plot.bar(ax=axes[0],color='k',alpha=0.5)
s1.plot.barh(ax=axes[1],color='k',alpha=0.5,)
fig.subplots_adjust(top=2 ,hspace=0.1)

# %% [markdown]
# With a DataFrame, bar plots group the values in each row together in a group in bars,
#  side by side, for each value.

# %%
df=pd.DataFrame(np.random.rand(6,4),index=('one two three four five six').split(),columns=list('abcd'))
df
# Out:
#               a         b         c         d
# one    0.620633  0.581934  0.679989  0.595507
# two    0.467597  0.932136  0.074771  0.611306
# three  0.487500  0.929257  0.016972  0.795278
# four   0.707333  0.409857  0.776933  0.247361
# five   0.521566  0.736905  0.057546  0.529230
# six    0.632425  0.247430  0.177480  0.089388

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# One can also plot stacked bargraph as by passing stacked=True in side plot argument.

# %%
df.plot.barh(stacked=True , alpha=0.6)
# Out:
# <AxesSubplot:>

# %% [markdown]
# If you want to compare different columns within a row (xticks) dont stack but if u want to compare column value over different row itt is help full to use stack (it helps to reduce number of graph needed)

# %% [markdown]
# A useful recipe for bar plots is to visualize a Series’s value frequency
# using value_counts: s.value_counts().plot.bar().

# %%
s1=pd.Series(['a','b','c','a','a','b','c','c','c','c'])
s1.value_counts().plot.bar(color='g')
plt.title('Frequency graph')
plt.xlabel('values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/mono0926/python-for-data-analytics/master/ch08/tips.csv'

# Specify delimiter as comma (assuming it's a comma-separated file)
tips = pd.read_csv(url)
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Now if we want to show percentage of each party size for each day then we can use bar plot.

# %%
party_count=pd.crosstab(tips['day'],tips['size'])
party_count
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
percentage=(party_count.div(party_count.sum(1),axis=0))
percentage
# Out:
# size         1         2         3         4         5         6
# day
# Fri   0.052632  0.842105  0.052632  0.052632  0.000000  0.000000
# Sat   0.022989  0.609195  0.206897  0.149425  0.011494  0.000000
# Sun   0.000000  0.513158  0.197368  0.236842  0.039474  0.013158
# Thur  0.016129  0.774194  0.064516  0.080645  0.016129  0.048387

# %%
percentage.plot.bar()
plt.subplots_adjust(right=2,top=1.4)
plt.title('Day wise party count')
# Out:
# Text(0.5, 1.0, 'Day wise party count')

# %% [markdown]
# Party size increases on weekends.

# %%
import seaborn as sns

tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.barplot(x='day',y='tip',data=tips,orient='v') #orient is usefull if both axis is numeric
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# Plotting functions in seaborn take a data argument, which can be a pandas Data
# Frame
# Because there are multiple
# observations for each value in the day, the bars are the average value of tip. The
# black lines drawn on the bars represent the 95% confidence interval

# %% [markdown]
# seaborn.barplot has a hue option that enables us to split by an additional categoricalvalue

# %%
sns.barplot(x='day',y='tip',hue='smoker',data=tips,) #addtional group based on smoker column
plt.subplots_adjust(right=1.3,top=1) #adjusting plot length and height
sns.set(style="whitegrid") #to get grid in background

# %%
sns.barplot(x='day',y='tip',hue='size',data=tips)  #average tip on each day and based on each party size
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# ### Histogram.

# %% [markdown]
# Histogram splits the  data points  into discrete, evenly spaced bins, and the number of data points in each bin is plotted

# %%
tips['tip'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Scatter plot.

# %% [markdown]
# Scatter plots are usefull for analysing relationship between two continous variables.
#
# Here we will be using macrodata from github.  We will select few variable then we calculate it's log and consecutive difference and plot scatter plot.

# %%
import pandas as pd
from io import StringIO
import requests

url = 'https://raw.githubusercontent.com/mono0926/python-for-data-analytics/master/ch08/macrodata.csv'

try:
    response = requests.get(url)
    data = pd.read_csv(StringIO(response.text))
    print(data.head())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
temp=data[['cpi', 'm1', 'tbilrate', 'unemp']]
trnsfrm=np.log(temp).diff()
trnsfrm.dropna(inplace=True)
trnsfrm.isnull().any()
# Out:
# cpi         False
# m1          False
# tbilrate    False
# unemp       False
# dtype: bool

# %%
sns.regplot('m1','unemp',data=trnsfrm)
# Out:
# C:\Users\shraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='m1', ylabel='unemp'>

# %% [markdown]
# ### Categorical data using factor plot.

# %% [markdown]
# What if we can form additional dimension using categorical data?. For this seaborn provides.factorplots.

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
import numpy as np
import seaborn as sns

sns.set(style='whitegrid') #to get white grid in background
sns.catplot(x='day',y='tip',hue='time',col='smoker',kind='bar',data=tips,estimator=np.min,legend=True)


#note : in old version catplot was called as factorplot

# %% [markdown]
# Possible values for kind parameter “point”, “bar”, “strip”, “swarm”, “box”, “violin”, or “boxen”.

# %%
sns.catplot(y='tip',x='day',row='time',col='smoker',data=tips[tips.tip<2],kind='bar'
           ,height=3.5  #adjust height of graph
           ,aspect=1.2)
#if u need you can add one more category as hue

# %%
sns.catplot(x='tip',y='day',kind='box' , data=tips,aspect=1.3)

# %% [markdown]
# This notebook teaches you the ropes to get up and running.
#
# Well,  the purpose of this article was to introduce fundamental data visualization techniques using pandas, matplotlib, and seaborn. If conveying data analysis results visually is integral to your work, I recommend exploring additional learning resources to delve deeper into the art of effective data visualization. The field is dynamic, with numerous online and print materials providing ample opportunities for practice and enhancement of your skills.
#
# #DataVisualization #DataAnalysis #DataScience #DataViz #LearningJourney"

# %% [markdown]
# Certainly, let's go for a more straightforward and informative approach:
#
# "Just created a Jupyter notebook for beginners diving into basic data visualization with Matplotlib, Seaborn, and Pandas. 📊🐍 If you're starting out in data analysis, this resource is tailored to help you understand the essentials. Check it out and feel free to explore the documentation of these libraries for further learning! 🚀 #DataVisualization #Matplotlib #Seaborn #Pandas #DataAnalysis #LearningResources"
